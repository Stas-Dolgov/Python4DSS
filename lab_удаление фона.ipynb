# %%
#УДАЛЕНИЕ ФОНА

# %%
from rembg import remove
from PIL import Image

# %%
image_man = Image.open('Python4DSS\image.png')
image_man
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\Стас\AppData\Local\Temp\ipykernel_4600\1039548833.py:1: SyntaxWarning: invalid escape sequence '\i'
#   image_man = Image.open('Python4DSS\image.png')
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=351x351>

# %%
#PlantUML
#NumPy
#Pandas

# %%
remove(Image.open('image.png'))
# Out:
# ...
# 100%|#######################################| 176M/176M [00:00<00:00, 87.1GB/s]
# <PIL.Image.Image image mode=RGBA size=351x351>

# %%
remove(Image.open('image_3.webp'))
# Out:
# <PIL.Image.Image image mode=RGBA size=400x300>

# %%
#PlantUML
#онлайн редактор для диаграм

# %%
import iplantuml

# %%
# %%plantuml
#
# class Car {
#     -field1
#     #field1
#
# }
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_ipython().run_cell_magic('plantuml', '', '\nclass Car {\n    -field1\n    #field1\n    \n}\n')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Стас\AppData\Local\Programs\Python\Python312\Lib\site-packages\iplantuml\__init__.py:101, in plantuml(line, cell)
#      99 output = None
# ...
